# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file=r"C:\Users\Amr\Desktop\Sales_Project\Sales_Marketing_Hr_Datasts-Your Full Name .xlsx"
sheet="Sales"
data=pd.read_excel(file,sheet)
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df=data
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
# std       92.085478         9.741443    20.174277         4.225841
#
#               SALES                      ORDERDATE       QTR_ID     MONTH_ID  \
# count   2823.000000                           2823  2823.000000  2823.000000
# mean    3553.889072  2004-05-11 00:16:49.989373056     2.717676     7.092455
# min      482.130000            2003-01-06 00:00:00     1.000000     1.000000
# ...

# %%
df.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.drop(columns="ADDRESSLINE2",inplace=True)
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0 2003-02-24  Shipped       1         2     2003  ...        2125557818
# 1 2003-05-07  Shipped       2         5     2003  ...        26.47.1555
# 2 2003-07-01  Shipped       3         7     2003  ...  +33 1 46 62 7555
# 3 2003-08-25  Shipped       3         8     2003  ...        6265557265
# 4 2003-10-10  Shipped       4        10     2003  ...        6505551386
#
#                     ADDRESSLINE1           CITY STATE POSTALCODE COUNTRY  \
# ...

# %%
sns.boxplot(data=df,x="SALES")
# Out:
# <Axes: xlabel='SALES'>

# %%
sns.boxplot(data=df,x="PRICEEACH")
# Out:
# <Axes: xlabel='PRICEEACH'>

# %%
sns.boxplot(data=df,x="MSRP",color="grey")
# Out:
# <Axes: xlabel='MSRP'>

# %%
df["SALES"].sum()
# Out:
# np.float64(10032628.85)

# %%
df.drop(columns="STATE",inplace=True)
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0         Land of Toys Inc.        2125557818        897 Long Airport Avenue
# ...

# %%
if "TERRITORY" in df.columns:
    df.drop(columns="TERRITORY",inplace=True)
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0 2003-02-24  Shipped       1         2     2003  ...    S10_1678
# 1 2003-05-07  Shipped       2         5     2003  ...    S10_1678
# 2 2003-07-01  Shipped       3         7     2003  ...    S10_1678
# 3 2003-08-25  Shipped       3         8     2003  ...    S10_1678
# 4 2003-10-10  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
df.isna().sum()
# Out:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# CITY                 0
# POSTALCODE          76
# COUNTRY              0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
df[df["POSTALCODE"].isna()]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49     100.00               14  5205.27
# 8           10201               22      98.57                2  2168.54
# 46          10333               26     100.00                3  3003.00
# 50          10381               36     100.00                3  8254.80
# 58          10159               37     100.00               17  5016.83
# ...           ...              ...        ...              ...      ...
# 2331        10159               23     100.00               12  2347.15
# 2436        10159               31      71.60               10  2219.60
# 2531        10384               49     100.00                1  6397.44
# 2543        10209               33      88.71                4  2927.43
# 2779        10209               48      44.69                3  2145.12
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# ...

# %%
d=df
d
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# ...

# %%
d.loc[(d["CITY"]=="San Francisco") & (df["POSTALCODE"].isna()), "POSTALCODE"]=94102

# %%
d.filter(items=["CITY","POSTALCODE"]).isna().sum()
# Out:
# CITY           0
# POSTALCODE    14
# dtype: int64

# %%
df.loc[(d["CITY"]=="San Francisco") & (df["POSTALCODE"].isna()), "POSTALCODE"]=94102

# %%
df["POSTALCODE"].isna().sum()
# Out:
# np.int64(14)

# %%
df[df["POSTALCODE"].isna()]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 115         10209               39     100.00                8  5197.92
# 295         10160               46     100.00                6  5294.14
# 398         10160               50     100.00                5  5182.00
# 604         10160               38      88.55                4  3364.90
# 944         10209               28     100.00                6  2817.92
# 1022        10160               20     100.00                1  3996.40
# 1224        10209               20     100.00                5  2498.60
# 1753        10209               43      82.21                1  3535.03
# 1796        10160               42      37.00                2  1554.00
# 1903        10209               36      77.59                2  2793.24
# 1953        10209               22      89.73                7  1974.06
# 1974        10160               35     100.00                3  4767.70
# ...

# %%
df.loc[(df["CITY"]=="Los Angeles") & (df["POSTALCODE"].isna()),"POSTALCODE"] = 90001

# %%
df["POSTALCODE"].isna().sum()
# Out:
# np.int64(0)

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0 2003-02-24  Shipped       1         2     2003  ...    S10_1678
# 1 2003-05-07  Shipped       2         5     2003  ...    S10_1678
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df["ORDERDATE"]
# Out:
# 0      2003-02-24
# 1      2003-05-07
# 2      2003-07-01
# 3      2003-08-25
# 4      2003-10-10
#           ...
# 2818   2004-12-02
# 2819   2005-01-31
# 2820   2005-03-01
# 2821   2005-03-28
# 2822   2005-05-06
# Name: ORDERDATE, Length: 2823, dtype: datetime64[ns]

# %%
len(df["CUSTOMERNAME"].unique())
# Out:
# 92

# %%
df["CUSTOMERNAME"].nunique()
# Out:
# 92

# %%
dis=df["CUSTOMERNAME"].drop_duplicates()

# %%
dis.value_counts().sum()
# Out:
# np.int64(92)

# %%
df["ORDERNUMBER"].nunique()
# Out:
# 307

# %%
t=df.groupby("CUSTOMERNAME")["ORDERNUMBER"].count().reset_index(name="Order number").sort_values(by="Order number",ascending=False).head(10)
t
# Out:
#                     CUSTOMERNAME  Order number
# 33         Euro Shopping Channel           259
# 55  Mini Gifts Distributors Ltd.           180
# 6     Australian Collectors, Co.            55
# 44             La Rochelle Gifts            53
# 0                 AV Stores, Co.            51
# 45             Land of Toys Inc.            49
# 67                 Rovelli Gifts            48
# 58            Muscle Machine Inc            48
# 3        Anna's Decorations, Ltd            46
# 75     Souveniers And Things Co.            46

# %%
df[["SALES"]].sum().rename("Total_Sales").to_frame().applymap("{:,}".format)
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\3157618255.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["SALES"]].sum().rename("Total_Sales").to_frame().applymap("{:,}".format)
#          Total_Sales
# SALES  10,032,628.85

# %%
t1=(df.groupby("YEAR_ID")["SALES"].sum().reset_index(name="Sales_years"))
t1.sort_values(by="Sales_years",ascending=False).applymap("{:,}".format)
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\2221547840.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   t1.sort_values(by="Sales_years",ascending=False).applymap("{:,}".format)
#   YEAR_ID   Sales_years
# 1   2,004   4,724,162.6
# 0   2,003  3,516,979.54
# 2   2,005  1,791,486.71

# %%
df["STATUS"].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
t2=(df.groupby("STATUS")["STATUS"].count().reset_index(name="No.Status"))
t2.sort_values(by="No.Status",ascending=False)
# Out:
#        STATUS  No.Status
# 5     Shipped       2617
# 0   Cancelled         60
# 4    Resolved         47
# 3     On Hold         44
# 2  In Process         41
# 1    Disputed         14

# %%
t3=(df.groupby("MONTH_ID")["SALES"].sum().reset_index(name="Sales_Month").applymap("{:,.0f}".format))
t3
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\3401070218.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   t3=(df.groupby("MONTH_ID")["SALES"].sum().reset_index(name="Sales_Month").applymap("{:,.0f}".format))
#    MONTH_ID Sales_Month
# 0         1     785,874
# 1         2     810,442
# 2         3     754,501
# 3         4     669,391
# 4         5     923,973
# 5         6     454,757
# 6         7     514,876
# 7         8     659,311
# 8         9     584,724
# 9        10   1,121,215
# 10       11   2,118,886
# 11       12     634,679

# %%
t4=(df.groupby("QTR_ID")["SALES"].sum().sort_values(ascending=False).reset_index(name="Sales_QTR").applymap("{:,.0f}".format))
t4
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\2944681269.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   t4=(df.groupby("QTR_ID")["SALES"].sum().sort_values(ascending=False).reset_index(name="Sales_QTR").applymap("{:,.0f}".format))
#   QTR_ID  Sales_QTR
# 0      4  3,874,780
# 1      1  2,350,818
# 2      2  2,048,120
# 3      3  1,758,911

# %%
t5=(df.groupby("CITY")["SALES"].sum().sort_values(ascending=False).reset_index(name="Sales_City").head(10))
t5
# Out:
#             CITY  Sales_City
# 0         Madrid  1082551.44
# 1     San Rafael   654858.06
# 2            NYC   560787.77
# 3      Singapore   288488.41
# 4          Paris   268944.68
# 5  San Francisco   224358.68
# 6    New Bedford   207874.86
# 7         Nantes   204304.86
# 8      Melbourne   200995.41
# 9     Brickhaven   165255.20

# %%
t6=(df.groupby("COUNTRY")["SALES"].sum().sort_values(ascending=False).reset_index(name="Sales_Country").head(10))
t6
# Out:
#      COUNTRY  Sales_Country
# 0        USA     3627982.83
# 1      Spain     1215686.92
# 2     France     1110916.52
# 3  Australia      630623.10
# 4         UK      478880.46
# 5      Italy      374674.31
# 6    Finland      329581.91
# 7     Norway      307463.70
# 8  Singapore      288488.41
# 9    Denmark      245637.15

# %%
sns.barplot(t1,x=t1["YEAR_ID"],y=t1["Sales_years"],palette="hls")
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\2796541589.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(t1,x=t1["YEAR_ID"],y=t1["Sales_years"],palette="hls")
# <Axes: xlabel='YEAR_ID', ylabel='Sales_years'>

# %%
s=t2.sort_values(by="No.Status",ascending=False)
sns.barplot(s,x="No.Status",y="STATUS",palette="Paired")
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\3536215420.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(s,x="No.Status",y="STATUS",palette="Paired")
# <Axes: xlabel='No.Status', ylabel='STATUS'>

# %%
sns.lineplot(df,x=df["MONTH_ID"],y=df["SALES"])
# Out:
# <Axes: xlabel='MONTH_ID', ylabel='SALES'>

# %%
ax1=sns.barplot(t5,x=t5["Sales_City"],y=t5["CITY"],palette="rocket")
for container in ax1.containers:
    ax1.bar_label(container,fmt="%.0f")
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\4187220027.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1=sns.barplot(t5,x=t5["Sales_City"],y=t5["CITY"],palette="rocket")

# %%
ax=sns.barplot(t6,x=t6["Sales_Country"],y=t6["COUNTRY"],palette="Set2")
for container in ax.containers:
    ax.bar_label(container,fmt="%.0f")
# Out:
# C:\Users\Amr\AppData\Local\Temp\ipykernel_10740\1874283148.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(t6,x=t6["Sales_Country"],y=t6["COUNTRY"],palette="Set2")

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0 2003-02-24  Shipped       1         2     2003  ...    S10_1678
# 1 2003-05-07  Shipped       2         5     2003  ...    S10_1678
# ...

# %%
Total_Sales=df["QUANTITYORDERED"] * df["PRICEEACH"]
Total_Sales
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       4900.00
#          ...
# 2818    2000.00
# 2819    2900.00
# 2820    4300.00
# 2821    2116.16
# 2822    3079.44
# Length: 2823, dtype: float64

# %%
df.insert(5,"Total_sales",Total_Sales)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_sales  ORDERDATE    STATUS  QTR_ID  MONTH_ID  ...  PRODUCTCODE  \
# ...

# %%
df=df.rename(columns={"Total_sales":"Total_Sales"})

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_Sales  ORDERDATE    STATUS  QTR_ID  MONTH_ID  ...  PRODUCTCODE  \
# ...

# %%
df=df.rename(columns={"ADDRESSLINE1":"ADDRESSLINE"})

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_Sales  ORDERDATE    STATUS  QTR_ID  MONTH_ID  ...  PRODUCTCODE  \
# ...

# %%
COGS=df["MSRP"]*df["QUANTITYORDERED"]
COGS
# Out:
# 0       2850
# 1       3230
# 2       3895
# 3       4275
# 4       4655
#         ...
# 2818    1080
# 2819    1566
# 2820    2322
# 2821    1836
# 2822    2538
# Length: 2823, dtype: int64

# %%
df.insert(6,"COGS",COGS)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_Sales  COGS  ORDERDATE    STATUS  QTR_ID  ...  PRODUCTCODE  \
# ...

# %%
Gross=df["Total_Sales"]-df["COGS"]

# %%
df.insert(7,"Gross_Profit",Gross)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_Sales  COGS  Gross_Profit  ORDERDATE    STATUS  ...  PRODUCTCODE  \
# ...

# %%
d=df
d
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_Sales  COGS  Gross_Profit  ORDERDATE    STATUS  ...  PRODUCTCODE  \
# ...

# %%
P_L=[]
for i in d["Gross_Profit"]:
    if i > 0:
        P_L.append("Profit")
    else:
        P_L.append("Loss")

# %%
P_L
# Out:
# ['Profit',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Profit',
#  'Profit',
#  'Loss',
#  'Profit',
#  'Profit',
#  'Profit',
#  'Profit',
#  'Profit',
#  'Profit',
#  'Profit',
#  'Loss',
#  'Profit',
#  'Profit',
#  'Profit',
#  'Loss',
#  'Profit',
#  'Profit',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Profit',
#  'Profit',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
#  'Loss',
# ...

# %%
df.insert(7,"Status",P_L)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       Total_Sales  COGS  Status  Gross_Profit  ORDERDATE  ... PRODUCTCODE  \
# ...

# %%
df.groupby("Status")["Status"].count().sort_values(ascending=False).reset_index(name="N.Status")
# Out:
#    Status  N.Status
# 0    Loss      1980
# 1  Profit       843

# %%
path=r"C:\Users\Amr\Desktop\Sales_Project\Sales.xlsx"
df.to_excel(path,index=False)

# %%
t0=(df.groupby("DEALSIZE")["SALES"].sum().sort_values(ascending=False).reset_index(name="Total_Sales"))
t0
# Out:
#   DEALSIZE  Total_Sales
# 0   Medium   6087432.24
# 1    Small   2643077.35
# 2    Large   1302119.26

# %%
plt.pie(t0["Total_Sales"],labels=t0["DEALSIZE"],startangle=90,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1de0bfbb8c0>,
# ...
#  [Text(-1.038704026190456, -0.3620689795822568, 'Medium'),
#   Text(1.0971234554238347, -0.07949920476875921, 'Small'),
#   Text(0.43619136437011974, 1.0098203274092543, 'Large')],
#  [Text(-0.5665658324675215, -0.19749217068123096, '60.7%'),
#   Text(0.598430975685728, -0.04336320260114138, '26.3%'),
#   Text(0.23792256238370166, 0.5508110876777751, '13.0%')])
